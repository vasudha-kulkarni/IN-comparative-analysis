# %%
import math
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
import kaleido

# %%
os.chdir('D:\\4th Year\\Semester 7\\BI4313 Sem Project\\IN-comparative-analysis\\IN-comparative-analysis\\Quant\\Updated_values')

# %%
song_q = pd.read_csv("01. Song_quantifiers.csv")
#song_q

# %%
sns.set_style("ticks")
g = sns.catplot(data=song_q, x="Species", y="No. of Unique Syllables", kind="box")
sns.swarmplot(data=song_q, x="Species", y="No. of Unique Syllables", color="k", size=5, ax=g.ax)

plt.xlabel('Species', fontsize = 12)
plt.ylabel('No. of Unique Syllables', fontsize = 12)
plt.ylim(bottom=0)
#plt.title('05 Start-Self transitions', fontsize = 14)
#plt.show()
plt.savefig('No. of unique syll.png', dpi = 600)

# %%
np.max(song_q['No. of Unique Start Syll'])
# Out:
# 4.0

# %%
sns.set_style("ticks")
#g = sns.swarmplot(data=song_q, x="Species", y="No. of Unique Start Syll", size=7)
g = sns.catplot(data=song_q, x="Species", y="No. of Unique Start Syll", kind="box")
sns.swarmplot(data=song_q, x="Species", y="No. of Unique Start Syll", color="k", size=5, ax=g.ax)
sns.despine()

max_syl = np.max(song_q['No. of Unique Start Syll'])+1

plt.xlabel('Species', fontsize = 12)
plt.ylabel('No. of Unique Start Syllables', fontsize = 12)
plt.yticks(np.arange(0, max_syl, step=1))
#plt.title('05 Start-Self transitions', fontsize = 14)
plt.show()
#plt.savefig('05 Start-Self transitions.png', dpi = 600)

# %%
sns.set_style("ticks")
g = sns.catplot(data=song_q, x="Species", y="Sequence Linearity", kind="box")
sns.swarmplot(data=song_q, x="Species", y="Sequence Linearity", color="k", size=5, ax=g.ax)

plt.xlabel('Species', fontsize = 12)
plt.ylabel('Sequence Linearity', fontsize = 12)
plt.ylim(bottom = 0)
#plt.title('05 Start-Self transitions', fontsize = 14)
plt.show()
#plt.savefig('05 Start-Self transitions.png', dpi = 600)

# %%
sns.set_style("ticks")
g = sns.catplot(data=song_q, x="Species", y="Sequence Consistency", kind="box")
sns.swarmplot(data=song_q, x="Species", y="Sequence Consistency", color="k", size=5, ax=g.ax)

plt.xlabel('Species', fontsize = 12)
plt.ylabel('Sequence Consistency', fontsize = 12)
plt.ylim(bottom = 0)
#plt.title('05 Start-Self transitions', fontsize = 14)
plt.show()
#plt.savefig('05 Start-Self transitions.png', dpi = 600)

# %%
sns.set_style("ticks")
g = sns.catplot(data=song_q, x="Species", y="Transition Entropy", kind="box")
sns.swarmplot(data=song_q, x="Species", y="Transition Entropy", color="k", size=5, ax=g.ax)

plt.xlabel('Species', fontsize = 12)
plt.ylabel('Transition Entropy', fontsize = 12)
plt.ylim(bottom = 0)
#plt.title('05 Start-Self transitions', fontsize = 14)
plt.show()
#plt.savefig('05 Start-Self transitions.png', dpi = 600)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------

# %%
song2_q = pd.read_csv("02. Syll_quantifiers.csv")

# %%
sns.set_style("ticks")
g = sns.catplot(data=song2_q, x="Species", y="Avg. repeats of first syll", kind="box")
sns.swarmplot(data=song2_q, x="Species", y="Avg. repeats of first syll", color="k", size=5, ax=g.ax)

plt.xlabel('Species', fontsize = 12)
plt.ylabel('Avg. repeats of first syllable', fontsize = 12)
plt.ylim(bottom=0)
#plt.title('05 Start-Self transitions', fontsize = 14)
plt.show()
#plt.savefig('05 Start-Self transitions.png', dpi = 600)

# %%
sns.set_style("ticks")
g = sns.scatterplot(data=song2_q, x="Avg. No. of Syll per song", y="Song duration", hue="Species")
#sns.swarmplot(data=song2_q, x="Species", y="Avg. repeats of first syll", color="k", size=5, ax=g.ax)

a = np.linspace(0, 135, 100)
b = np.linspace(0, 18, 100)
plt.plot(a, b, ':k')

plt.xlabel('Mean no. of syllables per song', fontsize = 12)
plt.ylabel('Mean song duration (s)', fontsize = 12)
plt.ylim(bottom=0, top=18)
plt.xlim(left=-1, right=135)

#plt.setp(g.get_legend().get_texts(), fontsize='2') 
plt.setp(g.get_legend().get_title(), fontsize='6')
g.legend(bbox_to_anchor=(1, 0.3))
#plt.title('05 Start-Self transitions', fontsize = 14)
plt.show()
#plt.savefig('05 Start-Self transitions.png', dpi = 600)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Blue - #3274a1
# Yellow - #e1812c
# Green - #3a923a
# Red - #c03d3e
#
# ["#3274a1", "#e1812c", "#3a923a", "#c03d3e"]

# %%
#data = pd.read_csv("03. Avg amplitude values.csv")
#data = pd.read_csv("04. Avg frequency values.csv")
#data = pd.read_csv("05. Avg syllable duration values.csv")
data = pd.read_csv("06. Avg internote interval values.csv")

# %%
sns.set_style("ticks")
plt.figure(dpi=300)
colors = ["#3274a1", "#e1812c", "#3a923a", "#c03d3e"]
species = ['BCC', 'BF', 'JF', 'ZF']
x = [1, 2, 3, 4, 5]

for j in range(len(species)):
    df1 = data.loc[data['Species'] == species[j]]
    df2 = df1.iloc[:, 2:]
    df_mean = np.array(np.mean(df2))
    df_sd = np.array(np.std(df2))
    for i in range(len(df1)-1):
        p = df1.iloc[i:i+1, :]
        q = np.array(p.iloc[:, 2:])
        y = q[0]
        plt.plot(x, y, linewidth=0.75, color=colors[j])
    plt.plot(x, df_mean, linewidth=1.5, color=colors[j], linestyle='dashed', label=species[j])

plt.legend(bbox_to_anchor=(1.2, 0.3))
#plt.ylim(top=50)

plt.xlabel('Syllable position', fontsize = 12)
plt.xticks(np.arange(1, 6, step=1))
plt.ylabel('Log Amplitude (dB)', fontsize = 12)
plt.show()

# %%
sns.set_style("ticks")
plt.figure(dpi=300)
colors = ["#3274a1", "#e1812c", "#3a923a", "#c03d3e"]
species = ['BCC', 'BF', 'JF', 'ZF']
x = [1, 2, 3, 4, 5]

for j in range(len(species)):
    df1 = data.loc[data['Species'] == species[j]]
    df2 = df1.iloc[:, 2:]
    df_mean = np.array(np.mean(df2))
    df_sd = np.array(np.std(df2))
    df_sem = np.array(np.std(df2)/np.sqrt(len(df1)))
    # for i in range(len(df1)-1):
    #     p = df1.iloc[i:i+1, :]
    #     q = np.array(p.iloc[:, 2:])
    #     y = q[0]
    #     plt.plot(x, y, linewidth=0.75, color=colors[j])
    plt.plot(x, df_mean, linewidth=1.5, color=colors[j], linestyle='dashed', label=species[j])
    plt.fill_between(x, df_mean-df_sem, df_mean+df_sem, color=colors[j], alpha=0.5)

plt.legend(bbox_to_anchor=(1.2, 0.3))
#plt.ylim(top=50)

plt.xlabel('Syllable position', fontsize = 12)
plt.xticks(np.arange(1, 6, step=1))
plt.ylabel('Internote interval (s)', fontsize = 12)
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %%
data = pd.read_csv("07. Start-Self Transition Prob.csv")
# Out:
#          Bird name Species Syll label  Start transition prob  \
# 0          BCC_M01     BCC      Start                   0.00
# 1          BCC_M01     BCC          i                   0.80
# 2          BCC_M01     BCC          j                   0.00
# 3          BCC_M01     BCC          a                   0.00
# 4          BCC_M01     BCC          b                   0.00
# ..             ...     ...        ...                    ...
# 280  ZF_ylw95ylw29      ZF          d                   0.00
# 281  ZF_ylw95ylw29      ZF        End                   0.00
# 282  ZF_ylw95ylw29      ZF          j                   0.10
# 283  ZF_ylw95ylw29      ZF          k                   0.27
# 284  ZF_ylw95ylw29      ZF          L                   0.00
#
#      Self-transition prob
# 0                    0.00
# 1                    0.00
# 2                    0.00
# 3                    0.00
# 4                    0.00
# ..                    ...
# 280                  0.00
# ...

# %%
sns.set_style("ticks")
plt.figure(dpi=600)
#g = sns.scatterplot(data=data, x="Start transition prob", y="Self-transition prob", hue="Species")
#sns.swarmplot(data=song2_q, x="Species", y="Avg. repeats of first syll", color="k", size=5, ax=g.ax)
sns.jointplot(data=data, x="Start transition prob", y="Self-transition prob", hue="Species", legend=None)

plt.xlabel('Beginning bout probability', fontsize = 12)
plt.ylabel('Self-transition probability', fontsize = 12)

#plt.xlim((0, 1))
#plt.ylim((0, 1))

#plt.setp(g.get_legend().get_title(), fontsize='6')
#g.legend(bbox_to_anchor=(1.2, 1))
plt.show()
#plt.savefig('05 Start-Self transitions.png', dpi = 600)

# %%
fig = px.scatter(data, x="Start transition prob", y="Self-transition prob", template="plotly_white",
    color="Species", marginal_x="histogram", marginal_y="histogram", color_discrete_sequence = ["#3274a1", "#e1812c", "#3a923a", "#c03d3e"])



fig.update_traces(
    marker=dict(size=7, symbol="diamond", line=dict(width=1, color="DarkSlateGrey")),
    selector=dict(mode="markers"),
)

fig.write_image("Start-Self trans.png")
# img_bytes = fig.to_image(format="png", width=600, height=600, scale=2)
# Image(img_bytes)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\VASUDH~1\AppData\Local\Temp/ipykernel_2736/303911593.py in <module>
#       9 )
#      10
# ---> 11 fig.write_image("Start-Self trans.png")
#      12 # img_bytes = fig.to_image(format="png", width=600, height=600, scale=2)
#      13 # Image(img_bytes)
#
# c:\Users\Vasudha Kulkarni\anaconda3\lib\site-packages\plotly\basedatatypes.py in write_image(self, *args, **kwargs)
#    3827         import plotly.io as pio
#    3828
# -> 3829         return pio.write_image(self, *args, **kwargs)
#    3830
#    3831     # Static helpers
#
# c:\Users\Vasudha Kulkarni\anaconda3\lib\site-packages\plotly\io\_kaleido.py in write_image(fig, file, format, scale, width, height, validate, engine)
#     265     # -------------
#     266     # Do this first so we don't create a file if image conversion fails
# --> 267     img_data = to_image(
# ...

# %%
import plotly.figure_factory as ff
import numpy as np

x1 = np.random.randn(200) - 2
x2 = np.random.randn(200)
x3 = np.random.randn(200) + 2

hist_data = [x1, x2, x3]

group_labels = ['Group 1', 'Group 2', 'Group 3']
colors = ['#A56CC1', '#A6ACEC', '#63F5EF']

# Create distplot with curve_type set to 'normal'
fig = ff.create_distplot(hist_data, group_labels, colors=colors,
                         bin_size=.2, show_rug=False)

# Add title
fig.update_layout(title_text='Hist and Curve Plot')
fig.show()

# %% [markdown]
# -----------------------------------------------------------------------------------------------------

# %%
df = pd.read_csv('06. Avg internote interval values.csv')
print(df.columns)

data = df.iloc[:, 2:]
data = np.array(data)
# Out:
# Index(['Bird name', 'Species', '#1', '#2', '#3', '#4', '#5'], dtype='object')

# %%
x = [1, 2, 3, 4, 5]
#colors = {'BCC' : 'tab:blue', 'BF' : 'tab:brown', 'JF' : 'tab:grey', 'ZF' : 'tab:green'}
#c=df['Species'].map(colors)

for i in range(len(df)):
    y = data[i]
    plt.plot(x, y, linewidth = 0.5)

plt.xlabel('Syllable position', fontsize = 12)
plt.ylabel('Internote interval (ms)', fontsize = 12)
plt.title('Duration of interval between initial syllables', fontsize = 14)

plt.show()
plt.savefig('04 internote interval init syll.png', dpi = 600)

# %%
df = pd.read_csv('07. Start-Self Transition Prob.csv')
df.columns

# %%
plt.scatter(df['Start transition prob'], df['Self-transition prob'])
# plt.xlim(0, 1.1)
# plt.ylim(-0.1, 1.1)
plt.xlabel('Initial occurrence probability', fontsize = 12)
plt.ylabel('Self-transition probability', fontsize = 12)
plt.title('05 Start-Self transitions', fontsize = 14)
#plt.show()
plt.savefig('05 Start-Self transitions.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', '#Syl', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('Number of syllables', fontsize = 12)
ax.set_title('No. of unique syllables across species', fontsize = 16)

#plt.show()
plt.savefig('01 Num syllables_2.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', '#SylSongBout', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('No. of syllables', fontsize = 12)
ax.set_title('Average number of syllables in song bouts', fontsize = 16)

#plt.show()
plt.savefig('01 Num syl in song bout_2.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', 'S_Lin', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('Sequence Linearity', fontsize = 12)
ax.set_title('Sequence Linearity across species', fontsize = 16)

#plt.show()
plt.savefig('02 Seq Lin_2.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', 'S_Con', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('Sequence Consistency', fontsize = 12)
ax.set_title('Sequence Consistency across species', fontsize = 16)

#plt.show()
plt.savefig('03 Seq Con_2.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', 'Trans_entropy', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('Transition Entropy', fontsize = 12)
ax.set_title('Transition entropy across species', fontsize = 16)

#plt.show()
plt.savefig('04 Trans entropy_2.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', '#StartSyl', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('No. of Unique First Syl', fontsize = 12)
ax.set_title('Number of unique first syllable in song bouts', fontsize = 16)

#plt.show()
plt.savefig('05 Num starting syll_2.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', 'FraStartSyll', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('Fraction of Unique First Syl', fontsize = 12)
ax.set_title('Fraction of unique first syllable in song bouts', fontsize = 16)

#plt.show()
plt.savefig('05 Fra starting syll_2.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', '#StartRepeat', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('No. of repeats of First Syl', fontsize = 12)
ax.set_title('Average number of repeats of first syllable in song bouts', fontsize = 16)

#plt.show()
plt.savefig('06 Num repeats of start syllable_2.png', dpi = 600)

# %%
sns.set()

fig, ax = plt.subplots()
sns.swarmplot('Species', 'AvgStartSelfTrans', data=df)
#ax.legend(loc='upper left', fontsize = 20, bbox_to_anchor = (0, 1.1))
ax.set_xlabel('Species', fontsize = 12)
ax.set_ylabel('Self-Transition Probability', fontsize = 12)
ax.set_title('Average self-transition prob of first syllable in song bouts (not normalised)', fontsize = 16)

#plt.show()
plt.savefig('07 Avg self trans of start syll.png', dpi = 600)
